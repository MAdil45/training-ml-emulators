# %% [markdown]
# # Machine Learned Emulators: Discovering Teleconnections and Quantifying Uncertainty in Coupled Socio-Hydrological Systems
#
# ## What You're About to Learn
# **Need to put abstract here**

# %% [markdown]
# ## Getting Started
# 1) Login to ```https://ciroh.awi.2i2c.cloud```
# 2) Pick Server Option -- Medium (or Small)
# 3) On the Image dropdown, pick ```DevCon24 workshop: Machine Learned Emulators```
# 4) Once loaded, go to the Git Menu... choose Clone Repository, and enter ```https://github.com/CIROH-UVM/training-ml-emulators.git```
#
# You should now see the training materials in your File Browser on the left side of your Jupyter interface.
